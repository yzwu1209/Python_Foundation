# %% [markdown]
# <h1><font color='red'>Activity</font></h1> - <strong>Week 12 - DataVis &amp; Plotting</strong><p>
# <i>For these exercises, we&rsquo;ll explore the components of a
#     plot/graph.</i></p>

# %%
# Activity - create a line graph
# Experiment: change colors, values, title, labels, etc.
# to get to know the parts of the figure.

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
#%config InlineBackend.figure_formats = ["retina"] # for ipad

x = np.linspace(0, 5, 20)
y = x ** 2
''' numpy.linspace. numpy. linspace (start, stop, num=50, endpoint=True, retstep=False, 
dtype=None)[source] Return evenly spaced numbers over a specified interval. 
see https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.linspace.html
'''

# matpolotlib object-oriented API
fig = plt.figure()
axes = fig.add_axes([0.1, 0.1, 0.8, 0.8])
# left, bottom, width, height (0:1)

axes.plot(x, y, 'r')
axes.set_xlabel('The X')
axes.set_ylabel('The Y')
axes.set_title('Title')
# Out:
# Text(0.5,1,'Title')

# %%
# the usual import statements
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline


## data plot-in-plot !
# The part-whole relationship in plotting is a precursor to
# applying a number of interactive techniques for exploring 
# data, such as "drill-down", "zoom", "data brushing", and
# countless mouse events for details-on-demans.
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) # main axes
axes2 = fig.add_axes([0.2,0.5,0.4,0.3]) #inset axes

#main figure
axes1.plot(x, y, 'b')
axes1.set_xlabel('x')
axes1.set_ylabel('y')
axes1.set_title('Main Title')

# insert figure
axes2.plot(y, x, 'r')
axes2.set_xlabel('y')
axes2.set_ylabel('x')
axes2.set_title('Insert title')


# EXPERIMENT 1: experiment with the color of the lines and 
# the figure outline.  One rule in design is to use the framework
# to establish a visual basis for the viewer, but then have that 
# framework reduce in visual importance; here the usual technique is
# to use "neutral gray", an ISO standard (cf. rgba(128,128,128,0.5))

# EXPERIMENT 2: background and forceground colors
# How to: with the fig defined, try applying 
# fig.patch.set_facecolor(<COLOR>) @ check out xkcd: colors.
'''
matplotlib.colors

Matplotlib recognizes the following formats to specify a color:
an RGB or RGBA tuple of float values in [0, 1] 
(e.g., (0.1, 0.2, 0.5) or (0.1, 0.2, 0.5, 0.3));
a hex RGB or RGBA string (e.g., '#0F0F0F' or '#0F0F0F0F');
a string representation of a float value in [0, 1] inclusive 
for gray level (e.g., '0.5');
one of {'b', 'g', 'r', 'c', 'm', 'y', 'k', 'w'};
a X11/CSS4 color name;
a name from the xkcd color survey; 
prefixed with 'xkcd:' (e.g., 'xkcd:sky blue');
one of {'tab:blue', 'tab:orange', 'tab:green', 'tab:red', 'tab:purple', 'tab:brown', 'tab:pink', 
'tab:gray', 'tab:olive', 'tab:cyan'} which are the Tableau Colors from the ‘T10’ categorical palette (which is the default color cycle);
a “CN” color spec, i.e. 'C' followed by a single digit, which is an index into the default property cycle 
(matplotlib.rcParams['axes.prop_cycle']); the indexing occurs at artist creation time and defaults to 
black if the cycle does not include color.
All string specifications of color, other than “CN”, are case-insensitive.
'''
## subplots.
# as in the asynch, create a figure and axes on the same line...
fig, axes = plt.subplots()
axes.plot(x, y, '#ff00e3')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('The Title')

# now the subplots ..
fig, axes = plt.subplots(nrows = 1, ncols = 2)
for ax in axes:
	ax.plot(x,y, 'r')
	ax.set_xlabel('x')
	ax.set_ylabel('y')
	ax.set_title('title')
	
fig.tight_layout()

# %%
fig, ax = plt.subplots()
ax.plot(x, x**2, x, x**3)
fig.tight_layout()

# inset:
inset_ax = fig.add_axes([0.2, 0.55, 0.35, 0.35]) # x, y, w, h
inset_ax.plot(x, x**2, x, x**3)
inset_ax.set_title("zoom near center")

# set axis range: (experiment)
inset_ax.set_xlim(-.2, .2)
inset_ax.set_ylim(-.005, .01)

# set axis tick locations
inset_ax.set_yticks([0, 0.005, 0.01])
inset_ax.set_xticks([-0.1, 0, .1])

# %%
# ACTIVITY: Experiment with output options.
# Change the size of the output (width, height)
# and get to know your environment by changeing FONTS
# when done, think about how you'll save your work.

# figure size, aspect ration and DPI

fig = plt.figure(figsize=(8,4), dpi=100)

fig, axes = plt.subplots(figsize=(12,3))
axes.plot(x,y,'r')
axes.set_xlabel('x')
axes.set_ylabel('y')
axes.set_title('New Figure')

## save your work (grin)
fig.savefig('myfiletest.png')

# 100 dpi is one thing, more?  Think about the output of the product...
fig.savefig('myfiletest.png', dpi=300)

# EXPERIMENT: the "all-in-one-shortcut approach" - as you know from the Asynch we can issue commands sequentially 
# or group them in a single config approach.

# Based on the above example, experiment with the below - make a working output.
# note that output ('papersize') can be expressed in pixels, inches, and even by the name of the paper, such as A4
# experiment with output values and see.
import matplotlib
from matplotlib.font_manager import FontProperties
# %config InlineBackend.print_figure_kwargs = {'bbox_inches':None}
# %config InlineBackend.rc = {'font.size': 10, 'figure.figsize': (10.0, 6.0), 'figure.facecolor': (1, 1, 1, 0), 'figure.subplot.bottom': 0.125, 'figure.edgecolor': (1, 1, 1, 0), 'figure.dpi': 72}
''' Add your own code below for practice. '''

# EXPERIMENT: Fonts contribute to legibility, consistency, branding, and design.  
# We *should* be able to output UTF-8 so be able to present in any script
# be sure to check out https://matplotlib.org/users/text_props.html#text-with-non-latin-glyphs
# Your computer setup might be different but for the fun of it experiment with
''' 
.Hiragino Kaku Gothic Interface
Adobe Arabic
Adobe Hewbrew
Arial
Arial Unicode MS
Avenir Next Condensed
Franklin Gothic Medium
FontAwesome
Lato
https://matplotlib.org/gallery/text_labels_and_annotations/fonts_demo.html
https://matplotlib.org/users/text_props.html
'''
matplotlib.rcParams['font.sans-serif'] = "Arial"
# Then, "ALWAYS use sans-serif fonts"
matplotlib.rcParams['font.family'] = "sans-serif"

axes.set_xlabel("")
axes.set_ylabel("TEST")
axes.set_title("Demo | سلم | 你好", fontsize=20)  # fix this, too.
# Out:
# Text(0.5,1,'Demo | سلم | 你好')

# %% [markdown]
# <h2>Users</h2> <p>Charts could be studied carefully to understand the data but end-users don't always stop to reflect or you might want to emphasize a trend or something about the
#     data.  Here symbols - be they stars, circles, squares or figures/icons/images - establish a meaningful framework for the user, help explain the data, and are more memorable (literally).

# %%
# EXPERIMENT: practice changing line size, line style, markers, and sizes.
# Once done playing with colors (try using the short cuts, RGB, hex color commands)
# Note: Altering the transparency or alpha channel of a color is a critical skill
# when dealing with large data sets where clusters share properties but not to the 
# same degree; 

# EXPERIMENT WITH THE DATA:
# x and y are not complicated; let's say, as happens in real practice, that you have
# a LOT of data - how to cause those data to display further apart? ... 
# try converting to a log ("log transformation")... very useful to practice.

### ### ###
# C O L O R S
ax.plot(x, x**2, 'b.-') # blue line with dots
ax.plot(x, x**3, 'g--') # green dashed line

# demo with 3 colored lines ...
fig, ax = plt.subplots()
ax.plot(x, x+1, color="red", alpha=0.5)
ax.plot(x, x+2, color='#1166ee')
ax.plot(x, x+3, color='#CCEE11')

### --------
fig, ax = plt.subplots(figsize=(12,6))

ax.plot(x, x+1, color="blue", linewidth=0.25)
ax.plot(x, x+2, color="blue", linewidth=0.50)
ax.plot(x, x+3, color="blue", linewidth=1.00)
ax.plot(x, x+4, color="blue", linewidth=2.00)

# possible linestype options ‘-‘, ‘--’, ‘-.’, ‘:’, ‘steps’
ax.plot(x, x+5, color="red", lw=2, linestyle='-')
ax.plot(x, x+6, color="red", lw=2, ls='-.')
ax.plot(x, x+7, color="red", lw=2, ls=':')

# custom dash
line, = ax.plot(x, x+8, color="black", lw=1.50)
line.set_dashes([5, 10, 15, 10]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(x, x+ 9, color="green", lw=2, ls='--', marker='+')
ax.plot(x, x+10, color="green", lw=2, ls='--', marker='o')
ax.plot(x, x+11, color="green", lw=2, ls='--', marker='s')
ax.plot(x, x+12, color="green", lw=2, ls='--', marker='1')

# marker size and color
ax.plot(x, x+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(x, x+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(x, x+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(x, x+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
       markerfacecolor="yellow", markeredgewidth=2, markeredgecolor="blue");
# Out:
# Text(0.5,1,'Log')

# %%
# EXPERIMENT: various 2d plots presented - experiment.
# see http://matplotlib.org/gallery.html

n = np.array([3,1,0,3,4,7])  # experiment with the data
fig, axes = plt.subplots(1, 4, figsize=(12,3)) # experiment with the fig sizes

axes[0].scatter(x, x + 0.25*np.random.randn(len(x)))
axes[0].set_title("scatter")
# experiment combining multiple scatter plots

axes[1].step(n, n**2, lw=2)
axes[1].set_title("step")

axes[2].bar(n, n**2, align="center", width=0.5, alpha=0.5)
axes[2].set_title("bar")

axes[3].fill_between(x, x**2, x**3, color="green", alpha=0.5);
axes[3].set_title("fill_between");

# Brrr! a polar plot
# polar plot using add_axes and polar projection
fig = plt.figure()
ax = fig.add_axes([0.0, 0.0, .6, .6], polar=True)
t = np.linspace(0, 2 * np.pi, 100)
ax.plot(t, t, color='pink', lw=3);

# %% [markdown]
# <hr/>
# <h1><font color='red'>Optional</font> - Some Demos</h1>
# <p>This section includes plots from <code>matplotlib</code>&rsquo;s documentation just to demonstrate to you some of the fun, cool things you can do.
# For practice&rsquo;s apply what you know about color, fig size, data ... consider importing your data from a csv file and see ... </p>

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
 
# Create data
N = 60
g1 = (0.6 + 0.6 * np.random.rand(N), np.random.rand(N),0.4+0.1*np.random.rand(N))
g2 = (0.4+0.3 * np.random.rand(N), 0.5*np.random.rand(N),0.1*np.random.rand(N))
g3 = (0.3*np.random.rand(N),0.3*np.random.rand(N),0.3*np.random.rand(N))
 
data = (g1, g2, g3)
colors = ("red", "green", "blue")
groups = ("coffee", "tea", "water") 
 
# Create plot
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1, facecolor="1.0")
ax = fig.gca(projection='3d')
 
for data, color, group in zip(data, colors, groups):
    x, y, z = data
    ax.scatter(x, y, z, alpha=0.8, c=color, edgecolors='none', s=30, label=group)
 
plt.title('Matplot 3d scatter plot')
plt.legend(loc=2)
plt.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Requested projection is different from current axis projection, creating new axis with requested projection.

# %% [markdown]
# This script is from one of the materials posted in the course online resources.<br />
# <img src="https://covers.oreillystatic.com/images/0636920034919/lrg.jpg" width="200px"/>

# %%
''' https://jakevdp.github.io/PythonDataScienceHandbook/04.04-density-and-contour-plots.html '''

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contour(X, Y, Z, 20, cmap='RdGy');  # red gray
plt.contourf(X, Y, Z, 20, cmap='RdGy')
plt.colorbar();

contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();
