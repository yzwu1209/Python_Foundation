# %% [markdown]
# ## Week 6 Assignment - W200 Python for Data Science, UC Berkeley MIDS
#
# Write code in this Jupyter Notebook to solve each of the following problems. Each problem should have its solution in a separate cell. Please upload this **notebook**, your **scrabble.py** file, the **sowpods.txt** file, and your **score_word** module to your GitHub repository in your SUBMISSIONS/week_06 folder by 11:59PM PST the night before class.

# %% [markdown]
# ## Objectives:
#
# - Read and understand PEP 8 standards
# - Use all of your previously gained knowledge together on a single program
# - Demonstrate how to import a user made module and function into python from another .py file
# - Demonstrate how to input command line arguments into a .py file

# %% [markdown]
# ## 6-1. PEP 8 Style Guide (reading and response)
#
# Your first task for this week is to write a **250 word reading response** to the article referenced below. In addition, please list **3 questions** that you have from the article. Please write your response in the markdown cell below.
#
# The writing response is a free response, so you may write about your reactions, such as an interesting thing that you saw in the article, something that really stuck out to you, etc.
#
# **Article**: [The PEP 8 Style Guide](https://www.python.org/dev/peps/pep-0008). This document is really important for Python coders because it describes best practices and customs.

# %% [markdown]
# YOUR ANSWER HERE
#
# The PEP 8 Style Guide is clear and concise in conveying the standards of meeting readability. By using “Yes” and “No” examples side by side, it gives reader a comparison that clearly explains why “No” example is not acceptable. Coding is not just to make the codes work. It is about readability as well. To ensure readability, there is so much detail that we should pay attention to. As a beginner of Python as well as coding in general, I have found myself fallen into quite a few pitfalls of non-readability. Here are some examples that I am quite surprised to learn:
# 1. Imports are always put at the top of the file and should be grouped in certain order. I immediately corrected this obvious mistake in my scrabble.py.
# 2. How whitespace should be handled in statements and expressions. I do understand that properly using whitespace would greatly improve readability. But I am confused as to why we should not use space around the = sign in the cases of keyword assignment and default parameters.
# 3. I truly agree with the guide in that “Comments that contradict the code are worse than no comments.” Sometimes in life, confusion does not come from no communications but rather miscommunications.
# 4. One final thought on the Guide is Tab vs. Space. I am quite surprised to find that the Guide would prefer space. Although it does make sense that tab could be interpreted differently than 4 spaces in some scenarios.

# %% [markdown]
# ## 6-2. Cheating at Scrabble
#
# Write a Python program that takes a Scrabble rack as a command-line argument and prints all valid Scrabble words that can be constructed from that rack, along with their Scrabble scores, sorted by score. Valid Scrabble words are provided in the data source below. A Scrabble rack is made up of 2 to 7 characters.
#
# Below are the requirements for the program:
# - This needs to be able to be run as a command line tool as shown below (not an input statement!)
# - Name the python file: `scrabble.py`
# - Include a function called `score_word` in a separate module. Import this function into your main solution code
# - Allow anywhere from 2-7 character tiles (letters A-Z) to be inputted
# - Do not restrict the number of same tiles (e.g., a user is allowed to input ZZZZZQQ)
# - Output the **total** list of valid Scrabble words that can be constructed from the rack as (score, word) tuples, sorted by score as shown below
# - Then output 'Total number of words:' and the total number
# - You need to handle input errors from the user and suggest what that error might be caused by and how to fix it (i.e., a helpful error message)
# - Implement wildcards as either `*` or `?`. A wildcard character can take any value A-Z. There can be a total of **only** two wild cards in any user input (that is, one of each character: one `*` and one `?`). Only use the `*` and `?` as wildcard characters.
# - Wildcard characters are scored as 0 points, just like in the real Scrabble game
# - Your program should take less than two minutes to run with 2 wildcards in the input - if it takes more time than that then your algorithm is not optimized very well!
# - Write docstrings for the functions and puts comments in your code.
# - You should only use the Python standard library in this assignment.  However, any function in the standard library is allowed.
#
# Extra Credit (+10 points):
# Allow a user to specify that a certain letter has to be at a certain location. Your program must work without it so this is completely optional. For the extra credit, locations of certain letters must be specified at the command line, and may not be some sort of user prompt.  Please put comments and a sample of how to run your extra credit in the extra credit cell of this notebook below - it is the last cell.
#
# An example invocation and output:
# ```
# $ python scrabble.py ZAEFIEE
# (17, feeze)
# (17, feaze)
# (16, faze)
# (15, fiz)
# (15, fez)
# (12, zee)
# (12, zea)
# (11, za)
# (6, fie)
# (6, fee)
# (6, fae)
# (5, if)
# (5, fe)
# (5, fa)
# (5, ef)
# (2, ee)
# (2, ea)
# (2, ai)
# (2, ae)
# Total number of words: 19
# ```
#
# The Data
#
# http://courses.cms.caltech.edu/cs11/material/advjava/lab1/sowpods.zip contains all words in the official SOWPODS word list, one word per line. You should download the word file and keep it in your repository so that the program is standalone (instead of accessing it over the web from Python).
#
# You can read data from a text file with the following code:
#
# ```
# with open("sowpods.txt","r") as infile:
#     raw_input = infile.readlines()
#     data = [datum.strip('\n') for datum in raw_input]
# ```
# This will show the first 6 words:
# ```
# print(data[0:6])
# ```
#
# Please use the dictionary below containing the letters and their Scrabble values:
#
# ```
# scores = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2,
#          "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3,
#          "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,
#          "r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,
#          "x": 8, "z": 10}
# ```
#
# Tips:
# - If you don't know what "scrabble" is or the basic background of the game please look it up online!
# - We recommend that you try to break down the problem into steps on your own before writing any code. Once you've scoped generally what you want to do, then start writing some code.  If you get stuck, go back to thinking about the problem rather than trying to fix lots of errors at the code level.
# - If you keep getting stuck, then check out: https://openhatch.org/wiki/Scrabble_challenge. This is where we got the idea for this assignment and it provides some helpful tips for guiding you along the way.  However, we would recommend that you try to implement this first before looking at the hints on the website.
#
# Good luck!

# %% [markdown]
# ### The code below will test your command line implementation of the scrabble.py code. We've made some of these tests available for you to try!

# %%
# Code for the testing

import subprocess
from nose.tools import assert_equal 
from nose.tools import assert_true
from nose.tools import assert_greater
from nose.tools import assert_less

# %%
""" Code runs and can produce at least one error message """

# no rack error
# !python scrabble.py
# Out:
# An error has occurred: Please provide either one or three inputs.

# %%
""" Does not fail due to trivial mistakes and takes correct wildcard characters """

# does not fail due to case
# !python scrabble.py "PENguin"

# takes wildcards
# !python scrabble.py "PEN*?in"
# Out:
# (10, penguin)
# (9, pening)
# (8, unpeg)
# (8, genip)
# (7, unpin)
# (7, unpen)
# (7, pung)
# (7, ping)
# (7, penni)
# (7, ingenu)
# (6, pug)
# (6, pine)
# (6, pig)
# (6, peni)
# (6, pein)
# (6, peg)
# (6, gup)
# (6, gip)
# (5, pun)
# (5, piu)
# (5, pin)
# (5, pie)
# (5, pen)
# (5, nip)
# (5, nep)
# (5, ginn)
# (5, gien)
# (5, genu)
# (5, ennui)
# (4, up)
# (4, pi)
# (4, pe)
# (4, nine)
# (4, neg)
# (4, gun)
# (4, gue)
# (4, gnu)
# (4, gin)
# (4, gie)
# (4, gen)
# (4, eng)
# (3, uni)
# (3, ug)
# (3, nun)
# (3, nie)
# (3, inn)
# (3, gu)
# (3, gi)
# (2, un)
# (2, nu)
# (2, ne)
# (2, in)
# (2, en)
# Total number of words: 53
# (15, pizes)
# (15, pized)
# (15, pique)
# (15, piezo)
# (15, peize)
# (15, equip)
# (14, zips)
# (14, zeps)
# (14, quip)
# (14, quep)
# (14, enzian)
# (13, zinke)
# (13, zines)
# (13, zineb)
# (13, zeins)
# (13, zap)
# (13, quine)
# (13, pixie)
# (13, pixes)
# (13, pixel)
# (12, zone)
# (12, zite)
# (12, zins)
# (12, zing)
# (12, zinc)
# (12, quin)
# (12, pixy)
# (12, pinkens)
# (12, jupe)
# (12, jinnee)
# (12, jimp)
# (12, jeep)
# (12, jape)
# (12, expo)
# (12, enjoin)
# (11, ziz)
# (11, zit)
# (11, zig)
# (11, zex)
# (11, zel)
# (11, zek)
# (11, zee)
# (11, zed)
# (11, zea)
# (11, xenon)
# (11, xenic)
# (11, xenia)
# (11, qis)
# (11, pinkie)
# (11, pinkey)
# (11, pinker)
# (11, pinked)
# (11, pfennig)
# (11, pekins)
# (11, nixie)
# (11, nixes)
# (11, nixer)
# (11, nixed)
# (11, ninja)
# (11, kippen)
# (11, jinns)
# (11, jinni)
# (11, jenny)
# (11, jap)
# (11, exing)
# (11, exine)
# (10, zo)
# (10, za)
# (10, wippen)
# (10, pyning)
# (10, pyeing)
# (10, pinyon)
# (10, pinyin)
# (10, pinky)
# (10, pinks)
# (10, pinko)
# (10, pinbone)
# (10, pikey)
# (10, pikes)
# (10, piker)
# (10, piked)
# (10, phenix)
# (10, phenic)
# (10, penks)
# (10, pekan)
# (10, nixy)
# (10, next)
# (10, kipes)
# (10, kepis)
# (10, join)
# (10, jive)
# (10, jinx)
# (10, jins)
# (10, jink)
# (10, jibe)
# (10, jeon)
# (10, jedi)
# (10, jean)
# (10, jann)
# (10, jane)
# (10, hippen)
# (10, exon)
# (10, exit)
# (9, yipes)
# (9, xis)
# (9, wipes)
# (9, wiper)
# (9, wiped)
# (9, viper)
# (9, pyxie)
# (9, pynes)
# (9, pyned)
# (9, pyins)
# (9, pincer)
# (9, piment)
# (9, piki)
# (9, pika)
# (9, piemen)
# (9, pieman)
# (9, piecen)
# (9, picine)
# (9, picene)
# (9, phone)
# (9, pheon)
# (9, phene)
# (9, pewit)
# (9, pepsin)
# (9, pepino)
# (9, penmen)
# (9, penman)
# (9, penguin)
# (9, pending)
# (9, pencil)
# (9, peke)
# (9, peinct)
# (9, pectin)
# (9, nipple)
# (9, nipper)
# (9, nipped)
# (9, mispen)
# (9, kype)
# (9, knop)
# (9, knap)
# (9, kips)
# (9, kipp)
# (9, kinone)
# (9, kilp)
# (9, kept)
# (9, keps)
# (9, kemp)
# (9, kelp)
# (9, keep)
# (9, jun)
# (9, joe)
# (9, jiz)
# (9, jig)
# (9, jib)
# (9, jew)
# (9, jeu)
# (9, jet)
# (9, jee)
# (9, jai)
# (9, incept)
# (9, impone)
# (9, impend)
# (9, exo)
# (8, yonnie)
# (8, ympe)
# (8, yips)
# (8, yeps)
# (8, yelp)
# (8, xu)
# (8, wisp)
# (8, winnle)
# (8, winner)
# (8, winned)
# (8, wimp)
# (8, whip)
# (8, wept)
# (8, weep)
# (8, venins)
# (8, venine)
# (8, veep)
# (8, tenpins)
# (8, spinone)
# (8, spinney)
# (8, spinnet)
# (8, spinner)
# (8, pyre)
# (8, pyic)
# (8, pyet)
# (8, pyes)
# (8, punnier)
# (8, pontine)
# (8, pipet)
# (8, pipes)
# (8, piper)
# (8, piped)
# (8, pinones)
# (8, pinnule)
# (8, pinnoed)
# (8, pinnies)
# (8, pinnets)
# (8, pinners)
# (8, pinnate)
# (8, pinnace)
# (8, pingle)
# (8, pinger)
# (8, pinged)
# (8, pinenes)
# (8, pinder)
# (8, pindan)
# (8, pinch)
# (8, pigpen)
# (8, pigeon)
# (8, piends)
# (8, piece)
# (8, phon)
# (8, phiz)
# (8, phis)
# (8, phew)
# (8, pfui)
# (8, pews)
# (8, pension)
# (8, penning)
# (8, pennine)
# (8, pennill)
# (8, pennies)
# (8, pennied)
# (8, pence)
# (8, peining)
# (8, pehs)
# (8, peening)
# (8, pecan)
# (8, peaning)
# (8, pantine)
# (8, pannier)
# (8, opening)
# (8, nippy)
# (8, ninepin)
# (8, nimps)
# (8, newing)
# (8, nempt)
# (8, neaping)
# (8, kop)
# (8, koine)
# (8, knive)
# (8, knife)
# (8, kinin)
# (8, kines)
# (8, jo)
# (8, ja)
# (8, ippon)
# (8, invent)
# (8, inkle)
# (8, inker)
# (8, inked)
# (8, impel)
# (8, imped)
# (8, hype)
# (8, hope)
# (8, hipt)
# (8, hips)
# (8, hesp)
# (8, hept)
# (8, heps)
# (8, hennin)
# (8, hemp)
# (8, help)
# (8, heap)
# (8, gipsen)
# (8, genips)
# (8, flip)
# (8, finner)
# (8, finned)
# (8, fainne)
# (8, epigon)
# (8, epics)
# (8, epha)
# (8, enwind)
# (8, enprint)
# (8, eking)
# (8, eikon)
# (8, dipnet)
# (8, cripe)
# (8, copen)
# (8, clipe)
# (8, biped)
# (8, bicep)
# (7, yup)
# (7, yince)
# (7, yap)
# (7, wop)
# (7, wizen)
# (7, winze)
# (7, winns)
# (7, winna)
# (7, winge)
# (7, winey)
# (7, wines)
# (7, wined)
# (7, wince)
# (7, widen)
# (7, whine)
# (7, wenny)
# (7, wap)
# (7, vixen)
# (7, visne)
# (7, vinew)
# (7, vines)
# (7, viner)
# (7, vined)
# (7, vimen)
# (7, veiny)
# (7, veins)
# (7, unripe)
# (7, unpins)
# (7, unpile)
# (7, unpent)
# (7, unpens)
# (7, unopen)
# (7, uniped)
# (7, tiepin)
# (7, tenpin)
# (7, supine)
# (7, spline)
# (7, spinny)
# (7, spinet)
# (7, spines)
# (7, spinel)
# (7, spined)
# (7, spinae)
# (7, snipes)
# (7, sniper)
# (7, sniped)
# (7, ripens)
# (7, repins)
# (7, repine)
# (7, rapine)
# (7, pyx)
# (7, pya)
# (7, purine)
# (7, punnet)
# (7, punner)
# (7, punned)
# (7, punkin)
# (7, punkie)
# (7, punier)
# (7, puisne)
# (7, pterin)
# (7, pruine)
# (7, proine)
# (7, prince)
# (7, pownie)
# (7, pontie)
# (7, ponies)
# (7, ponied)
# (7, ponent)
# (7, pointe)
# (7, pitten)
# (7, pitmen)
# (7, pirnie)
# (7, pipy)
# (7, pips)
# (7, pipi)
# (7, pipa)
# (7, pioney)
# (7, pioner)
# (7, pioned)
# (7, pintle)
# (7, pinons)
# (7, pinole)
# (7, pinnie)
# (7, pinnet)
# (7, pinner)
# (7, pinned)
# (7, pinnas)
# (7, pinnal)
# (7, pinnae)
# (7, pinken)
# (7, pinite)
# (7, pinion)
# (7, pining)
# (7, pinies)
# (7, pinier)
# (7, pings)
# (7, pingo)
# (7, pineta)
# (7, pinery)
# (7, pinene)
# (7, pineal)
# (7, pinang)
# (7, pimp)
# (7, pima)
# (7, pieing)
# (7, pics)
# (7, pick)
# (7, pica)
# (7, pht)
# (7, pho)
# (7, pernio)
# (7, perkin)
# (7, perfin)
# (7, peps)
# (7, pepo)
# (7, pensil)
# (7, pennon)
# (7, pennis)
# (7, pennia)
# (7, penni)
# (7, pennes)
# (7, penner)
# (7, penned)
# (7, pennal)
# (7, pennae)
# (7, pening)
# (7, penill)
# (7, penile)
# (7, penies)
# (7, penial)
# (7, pengo)
# (7, pendu)
# (7, pends)
# (7, penang)
# (7, peined)
# (7, peeing)
# (7, pecs)
# (7, peck)
# (7, pech)
# (7, peba)
# (7, patine)
# (7, pantie)
# (7, pannes)
# (7, panner)
# (7, panned)
# (7, panino)
# (7, panini)
# (7, paning)
# (7, panier)
# (7, pangen)
# (7, pained)
# (7, orpine)
# (7, opines)
# (7, opined)
# (7, nying)
# (7, nipter)
# (7, nifes)
# (7, nieve)
# (7, niefs)
# (7, newie)
# (7, nepits)
# (7, neks)
# (7, neive)
# (7, neifs)
# (7, nappie)
# (7, napkin)
# (7, naping)
# (7, mope)
# (7, mips)
# (7, minnie)
# (7, meninx)
# (7, mening)
# (7, lupine)
# (7, loipen)
# (7, lippen)
# (7, lineup)
# (7, leptin)
# (7, kyne)
# (7, kune)
# (7, knit)
# (7, knew)
# (7, knee)
# (7, kite)
# (7, kirn)
# (7, kins)
# (7, kino)
# (7, kink)
# (7, king)
# (7, kind)
# (7, kina)
# (7, kiln)
# (7, kike)
# (7, kier)
# (7, kief)
# (7, kibe)
# (7, kern)
# (7, kent)
# (7, kens)
# (7, keno)
# (7, keir)
# (7, keen)
# (7, kane)
# (7, kain)
# (7, kaie)
# (7, instep)
# (7, inspan)
# (7, inky)
# (7, inks)
# (7, infer)
# (7, incent)
# (7, inbent)
# (7, imps)
# (7, impi)
# (7, ikon)
# (7, ikan)
# (7, hyp)
# (7, hup)
# (7, hop)
# (7, hizen)
# (7, hinny)
# (7, hinge)
# (7, henny)
# (7, henna)
# (7, hemin)
# (7, hap)
# (7, gripe)
# (7, gipon)
# (7, fop)
# (7, finny)
# (7, fines)
# (7, finer)
# (7, fined)
# (7, fient)
# (7, fiend)
# (7, fenny)
# (7, fenis)
# (7, feint)
# (7, feign)
# (7, fap)
# (7, faine)
# (7, eying)
# (7, envoi)
# (7, enfix)
# (7, encina)
# (7, empt)
# (7, eiks)
# (7, ehing)
# (7, cope)
# (7, conine)
# (7, clip)
# (7, chip)
# (7, ceps)
# (7, cepe)
# (7, capi)
# (7, cape)
# (7, cannie)
# (7, canine)
# (7, bonnie)
# (7, boep)
# (7, blip)
# (7, binned)
# (7, binmen)
# (7, benzin)
# (7, bennis)
# (7, benign)
# (7, beep)
# (7, aspine)
# (7, apneic)
# (7, alpine)
# (6, yoni)
# (6, yite)
# (6, yins)
# (6, yike)
# (6, yeti)
# (6, yens)
# (6, yean)
# (6, wynn)
# (6, wren)
# (6, wive)
# (6, wite)
# (6, wise)
# (6, wire)
# (6, winy)
# (6, wins)
# (6, wino)
# (6, wink)
# (6, wing)
# (6, wind)
# (6, wile)
# (6, wife)
# (6, wiel)
# (6, wide)
# (6, wice)
# (6, whin)
# (6, when)
# (6, went)
# (6, wens)
# (6, wend)
# (6, wena)
# (6, weir)
# (6, weil)
# (6, weid)
# (6, ween)
# (6, wean)
# (6, wane)
# (6, wain)
# (6, vlei)
# (6, vive)
# (6, vite)
# (6, vise)
# (6, vire)
# (6, viny)
# (6, vint)
# (6, vins)
# (6, vino)
# (6, vina)
# (6, vile)
# (6, view)
# (6, vies)
# (6, vier)
# (6, vied)
# (6, vide)
# (6, vice)
# (6, vibe)
# (6, viae)
# (6, vent)
# (6, vend)
# (6, vena)
# (6, veil)
# (6, vane)
# (6, vain)
# (6, uptie)
# (6, upend)
# (6, unzip)
# (6, unrip)
# (6, unpin)
# (6, unpen)
# (6, unpeg)
# (6, unhip)
# (6, umpie)
# (6, tripe)
# (6, tepid)
# (6, tempi)
# (6, tapen)
# (6, swipe)
# (6, stipe)
# (6, spite)
# (6, spire)
# (6, spiny)
# (6, spins)
# (6, spink)
# (6, spine)
# (6, spina)
# (6, spile)
# (6, spike)
# (6, spies)
# (6, spier)
# (6, spiel)
# (6, spied)
# (6, spide)
# (6, spice)
# (6, spent)
# (6, spend)
# (6, speir)
# (6, speil)
# (6, spean)
# (6, spane)
# (6, spain)
# (6, snoep)
# (6, snipy)
# (6, snips)
# (6, snipe)
# (6, sneap)
# (6, slipe)
# (6, sipes)
# (6, siped)
# (6, sepic)
# (6, sepia)
# (6, ripes)
# (6, riper)
# (6, ripen)
# (6, riped)
# (6, repin)
# (6, redip)
# (6, purin)
# (6, punny)
# (6, punji)
# (6, punce)
# (6, pumie)
# (6, psion)
# (6, prune)
# (6, prone)
# (6, proin)
# (6, prize)
# (6, prise)
# (6, prion)
# (6, print)
# (6, prink)
# (6, prime)
# (6, pries)
# (6, prier)
# (6, prief)
# (6, pried)
# (6, pride)
# (6, price)
# (6, prent)
# (6, preif)
# (6, preen)
# (6, powin)
# (6, potin)
# (6, poney)
# (6, pones)
# (6, ponce)
# (6, pokie)
# (6, poise)
# (6, point)
# (6, poind)
# (6, plink)
# (6, pling)
# (6, plies)
# (6, plier)
# (6, plied)
# (6, pleon)
# (6, plena)
# (6, plane)
# (6, plain)
# (6, piton)
# (6, piste)
# (6, pises)
# (6, pirns)
# (6, pioye)
# (6, piony)
# (6, pions)
# (6, pinup)
# (6, pints)
# (6, pinto)
# (6, pinta)
# (6, pinot)
# (6, pinon)
# (6, pinny)
# (6, pinna)
# (6, piney)
# (6, pines)
# (6, pined)
# (6, pine)
# (6, pinas)
# (6, piles)
# (6, piler)
# (6, pilei)
# (6, piled)
# (6, pilea)
# (6, piing)
# (6, pigs)
# (6, piety)
# (6, piets)
# (6, pieta)
# (6, piert)
# (6, piers)
# (6, piend)
# (6, pians)
# (6, piano)
# (6, petti)
# (6, petit)
# (6, perns)
# (6, peris)
# (6, peril)
# (6, perai)
# (6, peony)
# (6, peons)
# (6, pents)
# (6, penny)
# (6, penne)
# (6, penna)
# (6, penis)
# (6, penie)
# (6, peni)
# (6, penes)
# (6, pened)
# (6, penal)
# (6, pelon)
# (6, pekin)
# (6, peise)
# (6, peins)
# (6, pein)
# (6, pegs)
# (6, pegh)
# (6, peens)
# (6, peds)
# (6, peans)
# (6, pavin)
# (6, paven)
# (6, patin)
# (6, paten)
# (6, panne)
# (6, panim)
# (6, panic)
# (6, panes)
# (6, panel)
# (6, paned)
# (6, pance)
# (6, paise)
# (6, paire)
# (6, paint)
# (6, pains)
# (6, paeon)
# (6, paean)
# (6, orpin)
# (6, opsin)
# (6, oping)
# (6, opine)
# (6, opens)
# (6, nyes)
# (6, nyed)
# (6, nipas)
# (6, niff)
# (6, niece)
# (6, niche)
# (6, nicer)
# (6, newt)
# (6, news)
# (6, neve)
# (6, netop)
# (6, nepit)
# (6, neper)
# (6, nemns)
# (6, nefs)
# (6, neeps)
# (6, neaps)
# (6, nappe)
# (6, napes)
# (6, naped)
# (6, mop)
# (6, monie)
# (6, mizen)
# (6, mixen)
# (6, minny)
# (6, minke)
# (6, minge)
# (6, mines)
# (6, miner)
# (6, mined)
# (6, mince)
# (6, minae)
# (6, miens)
# (6, meiny)
# (6, meint)
# (6, meins)
# (6, map)
# (6, lupin)
# (6, loipe)
# (6, lipin)
# (6, lepid)
# (6, lapin)
# (6, kye)
# (6, kue)
# (6, kon)
# (6, koi)
# (6, kit)
# (6, kis)
# (6, kir)
# (6, kif)
# (6, kid)
# (6, khi)
# (6, key)
# (6, kex)
# (6, ket)
# (6, keg)
# (6, kef)
# (6, ked)
# (6, keb)
# (6, kea)
# (6, kai)
# (6, kae)
# (6, input)
# (6, ingine)
# (6, ingenu)
# (6, info)
# (6, inept)
# (6, indent)
# (6, indene)
# (6, incle)
# (6, inbye)
# (6, inapt)
# (6, imine)
# (6, hyen)
# (6, hone)
# (6, hive)
# (6, hisn)
# (6, hire)
# (6, hint)
# (6, hins)
# (6, hing)
# (6, hind)
# (6, hike)
# (6, hies)
# (6, hied)
# (6, hide)
# (6, hewn)
# (6, hern)
# (6, hent)
# (6, hens)
# (6, hend)
# (6, heir)
# (6, heil)
# (6, heid)
# (6, hain)
# (6, haen)
# (6, grip)
# (6, gips)
# (6, ginner)
# (6, ginnel)
# (6, ginned)
# (6, gimp)
# (6, genip)
# (6, geep)
# (6, gape)
# (6, fone)
# (6, foin)
# (6, foen)
# (6, five)
# (6, firn)
# (6, fire)
# (6, fins)
# (6, fino)
# (6, fink)
# (6, fini)
# (6, find)
# (6, file)
# (6, fike)
# (6, fife)
# (6, fier)
# (6, fief)
# (6, fice)
# (6, fern)
# (6, fent)
# (6, fens)
# (6, fend)
# (6, feis)
# (6, feen)
# (6, fane)
# (6, fain)
# (6, eyne)
# (6, eyen)
# (6, evil)
# (6, even)
# (6, epris)
# (6, envy)
# (6, engine)
# (6, endrin)
# (6, ending)
# (6, eke)
# (6, dynein)
# (6, dupe)
# (6, drip)
# (6, dope)
# (6, dipt)
# (6, dips)
# (6, dinnle)
# (6, dinner)
# (6, dinned)
# (6, dimp)
# (6, dentin)
# (6, deep)
# (6, cup)
# (6, cunei)
# (6, crine)
# (6, cop)
# (6, conne)
# (6, conin)
# (6, cline)
# (6, cines)
# (6, chine)
# (6, cap)
# (6, brine)
# (6, bop)
# (6, bonne)
# (6, bonie)
# (6, binge)
# (6, bines)
# (6, biner)
# (6, benny)
# (6, benne)
# (6, benis)
# (6, being)
# (6, begin)
# (6, bap)
# (6, aspen)
# (6, arpen)
# (6, apnea)
# (6, aping)
# (6, apian)
# (5, yon)
# (5, yipe)
# (5, yid)
# (5, yex)
# (5, yew)
# (5, yet)
# (5, yes)
# (5, yeh)
# (5, yea)
# (5, yae)
# (5, wyn)
# (5, wye)
# (5, won)
# (5, woe)
# (5, wiz)
# (5, wit)
# (5, wis)
# (5, wipe)
# (5, wig)
# (5, wey)
# (5, wex)
# (5, wet)
# (5, wem)
# (5, wee)
# (5, wed)
# (5, web)
# (5, wan)
# (5, wai)
# (5, wae)
# (5, voe)
# (5, vis)
# (5, vim)
# (5, vig)
# (5, vid)
# (5, via)
# (5, vex)
# (5, vet)
# (5, veg)
# (5, vee)
# (5, van)
# (5, vae)
# (5, upon)
# (5, unrein)
# (5, unline)
# (5, unfine)
# (5, undine)
# (5, type)
# (5, trip)
# (5, topi)
# (5, tope)
# (5, tipt)
# (5, tips)
# (5, tipi)
# (5, tinnie)
# (5, tinner)
# (5, tinned)
# (5, tinmen)
# (5, tepa)
# (5, tennis)
# (5, temp)
# (5, tape)
# (5, tannie)
# (5, sype)
# (5, supe)
# (5, step)
# (5, spun)
# (5, spue)
# (5, spiv)
# (5, spit)
# (5, spin)
# (5, spim)
# (5, spik)
# (5, spif)
# (5, spie)
# (5, spic)
# (5, spew)
# (5, spet)
# (5, spek)
# (5, sped)
# (5, spec)
# (5, span)
# (5, spae)
# (5, snip)
# (5, snap)
# (5, slip)
# (5, skip)
# (5, skep)
# (5, sips)
# (5, sipe)
# (5, sinnet)
# (5, sinner)
# (5, sinned)
# (5, simp)
# (5, sienna)
# (5, ship)
# (5, shinne)
# (5, sept)
# (5, seps)
# (5, sennit)
# (5, seep)
# (5, sannie)
# (5, rype)
# (5, rope)
# (5, ronnie)
# (5, risp)
# (5, ript)
# (5, rips)
# (5, ripp)
# (5, ripe)
# (5, reps)
# (5, repp)
# (5, repo)
# (5, rennin)
# (5, renins)
# (5, reap)
# (5, rape)
# (5, ranine)
# (5, pyne)
# (5, pyin)
# (5, puri)
# (5, pure)
# (5, puny)
# (5, punt)
# (5, puns)
# (5, punk)
# (5, pung)
# (5, puna)
# (5, puli)
# (5, pule)
# (5, puke)
# (5, puir)
# (5, puer)
# (5, puce)
# (5, pube)
# (5, ptui)
# (5, psis)
# (5, prim)
# (5, prig)
# (5, prez)
# (5, prey)
# (5, prex)
# (5, prep)
# (5, prem)
# (5, pree)
# (5, pown)
# (5, pote)
# (5, pose)
# (5, porn)
# (5, pore)
# (5, pope)
# (5, poon)
# (5, pony)
# (5, pont)
# (5, pons)
# (5, ponk)
# (5, pong)
# (5, pone)
# (5, pond)
# (5, pome)
# (5, pole)
# (5, poke)
# (5, pois)
# (5, poet)
# (5, poep)
# (5, poem)
# (5, plue)
# (5, plim)
# (5, plie)
# (5, plex)
# (5, plew)
# (5, pled)
# (5, pleb)
# (5, plea)
# (5, plan)
# (5, pize)
# (5, pium)
# (5, pity)
# (5, pits)
# (5, pith)
# (5, pita)
# (5, piss)
# (5, piso)
# (5, pish)
# (5, pise)
# (5, pirs)
# (5, pirn)
# (5, pirl)
# (5, pipe)
# (5, pioy)
# (5, pion)
# (5, piny)
# (5, pint)
# (5, pins)
# (5, pink)
# (5, ping)
# (5, pina)
# (5, pin)
# (5, pily)
# (5, pill)
# (5, pili)
# (5, pile)
# (5, pila)
# (5, pike)
# (5, piet)
# (5, pies)
# (5, pier)
# (5, pied)
# (5, pie)
# (5, pice)
# (5, pias)
# (5, pian)
# (5, pial)
# (5, pets)
# (5, pest)
# (5, peso)
# (5, perv)
# (5, pert)
# (5, perp)
# (5, pern)
# (5, perm)
# (5, perk)
# (5, peri)
# (5, pere)
# (5, peon)
# (5, pent)
# (5, pens)
# (5, penk)
# (5, pene)
# (5, pend)
# (5, pen)
# (5, pelt)
# (5, pell)
# (5, pelf)
# (5, pele)
# (5, pela)
# (5, pees)
# (5, peer)
# (5, peep)
# (5, peen)
# (5, peel)
# (5, peek)
# (5, peed)
# (5, peat)
# (5, peas)
# (5, pear)
# (5, pean)
# (5, peal)
# (5, peak)
# (5, peag)
# (5, pawn)
# (5, pave)
# (5, pate)
# (5, pase)
# (5, pare)
# (5, pape)
# (5, pant)
# (5, pans)
# (5, pang)
# (5, pane)
# (5, pand)
# (5, pale)
# (5, pais)
# (5, pair)
# (5, pain)
# (5, pail)
# (5, paik)
# (5, paid)
# (5, page)
# (5, padi)
# (5, pace)
# (5, opes)
# (5, open)
# (5, oped)
# (5, online)
# (5, ondine)
# (5, olpe)
# (5, nys)
# (5, noup)
# (5, nope)
# (5, noop)
# (5, nips)
# (5, nipa)
# (5, nip)
# (5, ninety)
# (5, nims)
# (5, nimb)
# (5, niger)
# (5, nides)
# (5, nided)
# (5, nick)
# (5, nibs)
# (5, nerine)
# (5, neps)
# (5, nep)
# (5, nema)
# (5, neinei)
# (5, neigh)
# (5, neep)
# (5, neck)
# (5, nebs)
# (5, neap)
# (5, neanic)
# (5, narine)
# (5, naps)
# (5, nape)
# (5, napa)
# (5, nannie)
# (5, muni)
# (5, mite)
# (5, mise)
# (5, mire)
# (5, miny)
# (5, minx)
# (5, mint)
# (5, mino)
# (5, mink)
# (5, mini)
# (5, ming)
# (5, mind)
# (5, mina)
# (5, mime)
# (5, mile)
# (5, mike)
# (5, mice)
# (5, meri)
# (5, menu)
# (5, ment)
# (5, meno)
# (5, meng)
# (5, mene)
# (5, mend)
# (5, mean)
# (5, mani)
# (5, mane)
# (5, main)
# (5, lope)
# (5, lisp)
# (5, lips)
# (5, lipo)
# (5, lipe)
# (5, lipa)
# (5, linney)
# (5, linnet)
# (5, linned)
# (5, lineny)
# (5, linens)
# (5, linden)
# (5, limp)
# (5, lerp)
# (5, lept)
# (5, leps)
# (5, leep)
# (5, leap)
# (5, ky)
# (5, ko)
# (5, kipe)
# (5, kepi)
# (5, ka)
# (5, iwi)
# (5, ivy)
# (5, ionone)
# (5, intone)
# (5, intine)
# (5, intern)
# (5, intent)
# (5, intend)
# (5, insane)
# (5, inners)
# (5, innate)
# (5, innage)
# (5, ingle)
# (5, ingan)
# (5, indue)
# (5, indie)
# (5, index)
# (5, indew)
# (5, inch)
# (5, inby)
# (5, inanes)
# (5, inaner)
# (5, ifs)
# (5, iff)
# (5, ident)
# (5, icon)
# (5, ices)
# (5, icer)
# (5, iced)
# (5, ibex)
# (5, hye)
# (5, hun)
# (5, hui)
# (5, hue)
# (5, hon)
# (5, hoi)
# (5, hoe)
# (5, hit)
# (5, his)
# (5, him)
# (5, hid)
# (5, hic)
# (5, hey)
# (5, hex)
# (5, hew)
# (5, het)
# (5, hes)
# (5, her)
# (5, hem)
# (5, heh)
# (5, han)
# (5, hae)
# (5, gyp)
# (5, gynie)
# (5, gwine)
# (5, gup)
# (5, grein)
# (5, given)
# (5, ginny)
# (5, ginge)
# (5, genny)
# (5, genii)
# (5, genie)
# (5, genic)
# (5, gap)
# (5, fun)
# (5, fon)
# (5, foe)
# (5, fiz)
# (5, fix)
# (5, fit)
# (5, fir)
# (5, fil)
# (5, fig)
# (5, fid)
# (5, fib)
# (5, fez)
# (5, fey)
# (5, few)
# (5, feu)
# (5, fet)
# (5, fes)
# (5, fer)
# (5, fem)
# (5, feh)
# (5, feg)
# (5, fee)
# (5, fed)
# (5, fan)
# (5, fae)
# (5, eye)
# (5, ewt)
# (5, ewk)
# (5, ewe)
# (5, evo)
# (5, eve)
# (5, espy)
# (5, erning)
# (5, epos)
# (5, epic)
# (5, epee)
# (5, eonian)
# (5, ensign)
# (5, enring)
# (5, ennuis)
# (5, enlink)
# (5, emit)
# (5, emir)
# (5, emic)
# (5, eigne)
# (5, ehs)
# (5, eft)
# (5, efs)
# (5, eff)
# (5, ebon)
# (5, eaning)
# (5, dwine)
# (5, dup)
# (5, dop)
# (5, donne)
# (5, djinn)
# (5, dizen)
# (5, dinna)
# (5, dinge)
# (5, dines)
# (5, diner)
# (5, dined)
# (5, diene)
# (5, denis)
# (5, denim)
# (5, deign)
# (5, dap)
# (5, daine)
# (5, conn)
# (5, coni)
# (5, cone)
# (5, coin)
# (5, cive)
# (5, cite)
# (5, cire)
# (5, cion)
# (5, ciel)
# (5, cide)
# (5, chin)
# (5, cent)
# (5, cens)
# (5, ceil)
# (5, cedi)
# (5, cann)
# (5, cane)
# (5, cain)
# (5, bunn)
# (5, brin)
# (5, brie)
# (5, bren)
# (5, brei)
# (5, bone)
# (5, blin)
# (5, bize)
# (5, bite)
# (5, bise)
# (5, bint)
# (5, bins)
# (5, bink)
# (5, bing)
# (5, bind)
# (5, bile)
# (5, bike)
# (5, bier)
# (5, bide)
# (5, bice)
# (5, bent)
# (5, bens)
# (5, benj)
# (5, bene)
# (5, bend)
# (5, been)
# (5, bean)
# (5, bani)
# (5, bane)
# (5, apse)
# (5, apex)
# (5, apes)
# (5, aper)
# (5, aped)
# (4, zip)
# (4, zep)
# (4, yu)
# (4, yo)
# (4, yip)
# (4, yep)
# (4, ya)
# (4, wo)
# (4, venin)
# (4, urp)
# (4, urine)
# (4, ups)
# (4, upo)
# (4, untin)
# (4, untie)
# (4, unite)
# (4, union)
# (4, ump)
# (4, twp)
# (4, twine)
# (4, tup)
# (4, trine)
# (4, top)
# (4, tonne)
# (4, tip)
# (4, tinny)
# (4, tinge)
# (4, tines)
# (4, tined)
# (4, tinea)
# (4, thine)
# (4, thein)
# (4, tenon)
# (4, tenny)
# (4, tenno)
# (4, tenne)
# (4, tenia)
# (4, teind)
# (4, tap)
# (4, swine)
# (4, sup)
# (4, stein)
# (4, spy)
# (4, spa)
# (4, sop)
# (4, sonne)
# (4, snies)
# (4, snide)
# (4, skein)
# (4, siren)
# (4, sip)
# (4, singe)
# (4, sinew)
# (4, sines)
# (4, sined)
# (4, since)
# (4, silen)
# (4, sient)
# (4, siens)
# (4, shine)
# (4, sewin)
# (4, serin)
# (4, senti)
# (4, sensi)
# (4, senna)
# (4, sengi)
# (4, seine)
# (4, segni)
# (4, sdein)
# (4, sap)
# (4, saine)
# (4, ronne)
# (4, ronin)
# (4, riven)
# (4, risen)
# (4, rip)
# (4, rinse)
# (4, rines)
# (4, rhine)
# (4, rewin)
# (4, resin)
# (4, rep)
# (4, renne)
# (4, renin)
# (4, renig)
# (4, reins)
# (4, reink)
# (4, reign)
# (4, rap)
# (4, raine)
# (4, pye)
# (4, puy)
# (4, put)
# (4, pus)
# (4, pur)
# (4, pup)
# (4, pun)
# (4, pul)
# (4, puh)
# (4, pug)
# (4, pud)
# (4, pub)
# (4, pst)
# (4, psi)
# (4, pry)
# (4, pro)
# (4, pre)
# (4, poz)
# (4, pox)
# (4, pow)
# (4, pot)
# (4, pos)
# (4, pop)
# (4, poo)
# (4, pom)
# (4, pol)
# (4, poi)
# (4, poh)
# (4, pod)
# (4, poa)
# (4, ply)
# (4, plu)
# (4, pix)
# (4, piu)
# (4, pit)
# (4, pis)
# (4, pir)
# (4, pip)
# (4, pig)
# (4, pic)
# (4, pia)
# (4, pi)
# (4, phi)
# (4, pew)
# (4, pet)
# (4, pes)
# (4, per)
# (4, pep)
# (4, peh)
# (4, peg)
# (4, pee)
# (4, ped)
# (4, pec)
# (4, pea)
# (4, pe)
# (4, pay)
# (4, pax)
# (4, paw)
# (4, pav)
# (4, pat)
# (4, pas)
# (4, par)
# (4, pap)
# (4, pan)
# (4, pam)
# (4, pal)
# (4, pah)
# (4, pad)
# (4, pac)
# (4, ovine)
# (4, oup)
# (4, opt)
# (4, ops)
# (4, ope)
# (4, oop)
# (4, onned)
# (4, onion)
# (4, olein)
# (4, numen)
# (4, nudie)
# (4, nonis)
# (4, nonet)
# (4, nones)
# (4, nonce)
# (4, nomen)
# (4, noise)
# (4, noint)
# (4, nitre)
# (4, niton)
# (4, nites)
# (4, niter)
# (4, nisse)
# (4, nisei)
# (4, ninth)
# (4, ninon)
# (4, ninny)
# (4, nines)
# (4, nine)
# (4, nigh)
# (4, nids)
# (4, nidi)
# (4, neons)
# (4, nenes)
# (4, nelis)
# (4, neist)
# (4, negs)
# (4, neds)
# (4, nap)
# (4, nance)
# (4, naive)
# (4, naevi)
# (4, mun)
# (4, mon)
# (4, moi)
# (4, moe)
# (4, mna)
# (4, miz)
# (4, mix)
# (4, mis)
# (4, mir)
# (4, mim)
# (4, mil)
# (4, mig)
# (4, mid)
# (4, mic)
# (4, mib)
# (4, mew)
# (4, meu)
# (4, met)
# (4, mes)
# (4, mem)
# (4, mel)
# (4, meg)
# (4, mee)
# (4, med)
# (4, man)
# (4, mae)
# (4, lop)
# (4, liven)
# (4, lip)
# (4, linny)
# (4, linns)
# (4, linin)
# (4, liney)
# (4, lines)
# (4, liner)
# (4, linen)
# (4, lined)
# (4, limen)
# (4, liken)
# (4, ligne)
# (4, liens)
# (4, liane)
# (4, levin)
# (4, lep)
# (4, lenti)
# (4, lenis)
# (4, lap)
# (4, kip)
# (4, kep)
# (4, jinne)
# (4, isnae)
# (4, irone)
# (4, inurn)
# (4, inure)
# (4, inter)
# (4, intel)
# (4, inset)
# (4, inrun)
# (4, inner)
# (4, inned)
# (4, inlet)
# (4, inion)
# (4, ingo)
# (4, inert)
# (4, inerm)
# (4, inane)
# (4, imp)
# (4, idle)
# (4, ides)
# (4, idem)
# (4, idee)
# (4, idea)
# (4, icy)
# (4, ick)
# (4, ich)
# (4, ho)
# (4, hm)
# (4, hip)
# (4, hep)
# (4, ha)
# (4, grin)
# (4, gren)
# (4, gone)
# (4, glen)
# (4, glei)
# (4, give)
# (4, gite)
# (4, girn)
# (4, gip)
# (4, gins)
# (4, gink)
# (4, ging)
# (4, gies)
# (4, gied)
# (4, gibe)
# (4, genu)
# (4, gent)
# (4, gens)
# (4, gene)
# (4, gena)
# (4, geit)
# (4, gean)
# (4, gane)
# (4, gain)
# (4, gaen)
# (4, fy)
# (4, fa)
# (4, ettin)
# (4, ering)
# (4, eosin)
# (4, entia)
# (4, enoki)
# (4, ennui)
# (4, ennog)
# (4, enlit)
# (4, eniac)
# (4, engs)
# (4, ends)
# (4, emu)
# (4, ems)
# (4, emo)
# (4, eme)
# (4, elsin)
# (4, eloin)
# (4, elint)
# (4, elfin)
# (4, eldin)
# (4, elain)
# (4, eide)
# (4, egis)
# (4, edit)
# (4, ecu)
# (4, eco)
# (4, ech)
# (4, ebb)
# (4, dyne)
# (4, dune)
# (4, done)
# (4, doen)
# (4, djin)
# (4, dive)
# (4, dite)
# (4, dire)
# (4, dip)
# (4, dint)
# (4, dins)
# (4, dino)
# (4, dink)
# (4, ding)
# (4, dime)
# (4, dike)
# (4, diet)
# (4, dies)
# (4, diel)
# (4, died)
# (4, dieb)
# (4, dice)
# (4, desi)
# (4, dern)
# (4, deny)
# (4, dent)
# (4, dens)
# (4, dene)
# (4, deli)
# (4, deil)
# (4, deif)
# (4, deid)
# (4, defi)
# (4, deen)
# (4, dean)
# (4, cue)
# (4, con)
# (4, cit)
# (4, cis)
# (4, cig)
# (4, cid)
# (4, chi)
# (4, che)
# (4, cep)
# (4, cel)
# (4, cee)
# (4, can)
# (4, bye)
# (4, bun)
# (4, bon)
# (4, boi)
# (4, biz)
# (4, bit)
# (4, bis)
# (4, bio)
# (4, big)
# (4, bid)
# (4, bib)
# (4, bez)
# (4, bey)
# (4, bet)
# (4, bes)
# (4, benni)
# (4, bel)
# (4, beg)
# (4, bee)
# (4, bed)
# (4, ban)
# (4, azine)
# (4, avine)
# (4, asp)
# (4, apt)
# (4, app)
# (4, apo)
# (4, ape)
# (4, annex)
# (4, anise)
# (4, anion)
# (4, anime)
# (4, anile)
# (4, anent)
# (4, amp)
# (4, amine)
# (4, alp)
# (4, aline)
# (4, alien)
# (4, ainee)
# (3, zine)
# (3, zein)
# (3, winn)
# (3, wine)
# (3, vine)
# (3, vein)
# (3, up)
# (3, unit)
# (3, unis)
# (3, unde)
# (3, unci)
# (3, unce)
# (3, unbe)
# (3, unai)
# (3, tyne)
# (3, tyin)
# (3, twin)
# (3, tune)
# (3, trin)
# (3, trie)
# (3, tone)
# (3, tite)
# (3, tire)
# (3, tiny)
# (3, tint)
# (3, tins)
# (3, tink)
# (3, ting)
# (3, tine)
# (3, tind)
# (3, time)
# (3, tile)
# (3, tike)
# (3, tige)
# (3, ties)
# (3, tier)
# (3, tied)
# (3, tide)
# (3, tice)
# (3, thin)
# (3, then)
# (3, tern)
# (3, tent)
# (3, tens)
# (3, tene)
# (3, tend)
# (3, teil)
# (3, teen)
# (3, tane)
# (3, tain)
# (3, syne)
# (3, syen)
# (3, sunn)
# (3, stie)
# (3, sten)
# (3, sone)
# (3, snye)
# (3, snit)
# (3, snig)
# (3, snib)
# (3, snee)
# (3, sned)
# (3, sneb)
# (3, skin)
# (3, sken)
# (3, size)
# (3, site)
# (3, sire)
# (3, sins)
# (3, sink)
# (3, sinh)
# (3, sing)
# (3, sine)
# (3, sind)
# (3, sile)
# (3, sike)
# (3, sign)
# (3, sies)
# (3, sien)
# (3, side)
# (3, sice)
# (3, shin)
# (3, sewn)
# (3, sent)
# (3, sens)
# (3, sene)
# (3, send)
# (3, sena)
# (3, semi)
# (3, seis)
# (3, seir)
# (3, seil)
# (3, seik)
# (3, seif)
# (3, seen)
# (3, sean)
# (3, sane)
# (3, sain)
# (3, rune)
# (3, ruin)
# (3, rone)
# (3, roin)
# (3, rive)
# (3, rite)
# (3, rise)
# (3, rins)
# (3, rink)
# (3, ring)
# (3, rine)
# (3, rind)
# (3, rime)
# (3, rile)
# (3, rife)
# (3, riem)
# (3, riel)
# (3, ride)
# (3, rice)
# (3, reny)
# (3, rent)
# (3, rens)
# (3, renk)
# (3, rend)
# (3, reis)
# (3, rein)
# (3, reik)
# (3, reif)
# (3, reen)
# (3, rean)
# (3, rani)
# (3, rain)
# (3, po)
# (3, pa)
# (3, oxen)
# (3, oven)
# (3, op)
# (3, onie)
# (3, ones)
# (3, oner)
# (3, once)
# (3, omen)
# (3, oint)
# (3, oink)
# (3, nuns)
# (3, nuke)
# (3, nude)
# (3, nown)
# (3, noun)
# (3, note)
# (3, nose)
# (3, nori)
# (3, noon)
# (3, noni)
# (3, nong)
# (3, none)
# (3, nona)
# (3, nome)
# (3, nole)
# (3, noir)
# (3, noil)
# (3, noes)
# (3, noel)
# (3, nodi)
# (3, node)
# (3, nixe)
# (3, nits)
# (3, nite)
# (3, nisi)
# (3, nish)
# (3, nirl)
# (3, nils)
# (3, nill)
# (3, nife)
# (3, nies)
# (3, nief)
# (3, nied)
# (3, nie)
# (3, nide)
# (3, nice)
# (3, nevi)
# (3, neum)
# (3, neuk)
# (3, nett)
# (3, nets)
# (3, nete)
# (3, nest)
# (3, ness)
# (3, nesh)
# (3, nerk)
# (3, nerd)
# (3, neon)
# (3, nene)
# (3, nemn)
# (3, neif)
# (3, neem)
# (3, need)
# (3, neat)
# (3, near)
# (3, neal)
# (3, nazi)
# (3, naze)
# (3, nave)
# (3, nare)
# (3, naoi)
# (3, nans)
# (3, nane)
# (3, nana)
# (3, name)
# (3, nain)
# (3, nail)
# (3, naik)
# (3, naif)
# (3, nabe)
# (3, naan)
# (3, my)
# (3, mu)
# (3, mo)
# (3, mm)
# (3, mine)
# (3, mien)
# (3, mein)
# (3, ma)
# (3, lyne)
# (3, lwei)
# (3, lune)
# (3, lone)
# (3, loin)
# (3, live)
# (3, lite)
# (3, lire)
# (3, lion)
# (3, liny)
# (3, lint)
# (3, lins)
# (3, lino)
# (3, linn)
# (3, link)
# (3, ling)
# (3, line)
# (3, lind)
# (3, limn)
# (3, lime)
# (3, like)
# (3, life)
# (3, lieu)
# (3, lies)
# (3, lier)
# (3, lien)
# (3, lief)
# (3, lied)
# (3, lice)
# (3, lent)
# (3, lens)
# (3, leno)
# (3, leng)
# (3, lend)
# (3, leis)
# (3, leir)
# (3, lean)
# (3, lane)
# (3, lain)
# (3, kine)
# (3, jinn)
# (3, iure)
# (3, item)
# (3, isna)
# (3, isle)
# (3, iron)
# (3, ires)
# (3, ired)
# (3, ions)
# (3, into)
# (3, inti)
# (3, inro)
# (3, inns)
# (3, inn)
# (3, inly)
# (3, inia)
# (3, ilex)
# (3, ilea)
# (3, igg)
# (3, ids)
# (3, gun)
# (3, gue)
# (3, gon)
# (3, goe)
# (3, gnu)
# (3, git)
# (3, gis)
# (3, gio)
# (3, ginn)
# (3, gig)
# (3, gif)
# (3, gien)
# (3, gid)
# (3, gib)
# (3, ghi)
# (3, gey)
# (3, get)
# (3, geo)
# (3, gem)
# (3, gel)
# (3, gee)
# (3, ged)
# (3, gan)
# (3, gae)
# (3, fine)
# (3, feni)
# (3, euoi)
# (3, etui)
# (3, etna)
# (3, etic)
# (3, eten)
# (3, esne)
# (3, erns)
# (3, erne)
# (3, eric)
# (3, eons)
# (3, eoan)
# (3, enuf)
# (3, enow)
# (3, enol)
# (3, enew)
# (3, enes)
# (3, elhi)
# (3, elan)
# (3, eish)
# (3, eine)
# (3, eina)
# (3, eild)
# (3, ego)
# (3, egg)
# (3, eevn)
# (3, eds)
# (3, edh)
# (3, earn)
# (3, eans)
# (3, dye)
# (3, dun)
# (3, dui)
# (3, due)
# (3, don)
# (3, doe)
# (3, div)
# (3, dit)
# (3, dis)
# (3, dine)
# (3, dim)
# (3, dig)
# (3, dif)
# (3, did)
# (3, dib)
# (3, dey)
# (3, dex)
# (3, dew)
# (3, dev)
# (3, deni)
# (3, del)
# (3, deg)
# (3, def)
# (3, dee)
# (3, deb)
# (3, dan)
# (3, dae)
# (3, cine)
# (3, ch)
# (3, by)
# (3, bo)
# (3, bine)
# (3, bien)
# (3, beni)
# (3, bein)
# (3, ba)
# (3, ayin)
# (3, aune)
# (3, anti)
# (3, ante)
# (3, anon)
# (3, anns)
# (3, anno)
# (3, anna)
# (3, anis)
# (3, anil)
# (3, anew)
# (3, anes)
# (3, ance)
# (3, anan)
# (3, amin)
# (3, amie)
# (3, amen)
# (3, akin)
# (3, airn)
# (3, ains)
# (3, aine)
# (3, aide)
# (3, agin)
# (3, agen)
# (3, aeon)
# (3, acne)
# (2, zin)
# (2, yin)
# (2, yen)
# (2, win)
# (2, wen)
# (2, vin)
# (2, vie)
# (2, ute)
# (2, use)
# (2, urn)
# (2, ure)
# (2, uns)
# (2, uni)
# (2, ule)
# (2, uke)
# (2, uey)
# (2, tye)
# (2, tun)
# (2, tui)
# (2, ton)
# (2, toe)
# (2, tix)
# (2, tit)
# (2, tis)
# (2, tin)
# (2, til)
# (2, tig)
# (2, tie)
# (2, tid)
# (2, tic)
# (2, the)
# (2, tex)
# (2, tew)
# (2, tet)
# (2, tes)
# (2, ten)
# (2, tel)
# (2, teg)
# (2, tef)
# (2, tee)
# (2, ted)
# (2, tec)
# (2, tea)
# (2, tan)
# (2, tai)
# (2, tae)
# (2, syn)
# (2, sye)
# (2, sun)
# (2, sui)
# (2, sue)
# (2, sri)
# (2, son)
# (2, sny)
# (2, ski)
# (2, six)
# (2, sit)
# (2, sis)
# (2, sir)
# (2, sin)
# (2, sim)
# (2, sik)
# (2, sif)
# (2, sic)
# (2, sib)
# (2, she)
# (2, sez)
# (2, sey)
# (2, sex)
# (2, sew)
# (2, set)
# (2, ser)
# (2, sen)
# (2, sel)
# (2, sei)
# (2, seg)
# (2, see)
# (2, sed)
# (2, sec)
# (2, sea)
# (2, san)
# (2, sai)
# (2, sae)
# (2, rye)
# (2, run)
# (2, rue)
# (2, roe)
# (2, riz)
# (2, rit)
# (2, rin)
# (2, rim)
# (2, rig)
# (2, rif)
# (2, rid)
# (2, rib)
# (2, ria)
# (2, rez)
# (2, rex)
# (2, rew)
# (2, rev)
# (2, ret)
# (2, res)
# (2, reo)
# (2, ren)
# (2, rem)
# (2, rei)
# (2, reh)
# (2, reg)
# (2, ref)
# (2, ree)
# (2, red)
# (2, rec)
# (2, reb)
# (2, ran)
# (2, rai)
# (2, oye)
# (2, own)
# (2, owe)
# (2, ose)
# (2, ore)
# (2, oon)
# (2, ony)
# (2, ons)
# (2, ono)
# (2, one)
# (2, ole)
# (2, oke)
# (2, oil)
# (2, oik)
# (2, oes)
# (2, ode)
# (2, obi)
# (2, obe)
# (2, nye)
# (2, nut)
# (2, nus)
# (2, nur)
# (2, nun)
# (2, nub)
# (2, nth)
# (2, noy)
# (2, nox)
# (2, now)
# (2, not)
# (2, nos)
# (2, nor)
# (2, noo)
# (2, non)
# (2, nom)
# (2, noh)
# (2, nog)
# (2, nod)
# (2, nob)
# (2, nix)
# (2, nit)
# (2, nis)
# (2, nim)
# (2, nil)
# (2, nid)
# (2, nib)
# (2, new)
# (2, net)
# (2, nek)
# (2, neg)
# (2, nef)
# (2, nee)
# (2, ned)
# (2, neb)
# (2, ne)
# (2, nay)
# (2, naw)
# (2, nat)
# (2, nas)
# (2, nan)
# (2, nam)
# (2, nah)
# (2, nag)
# (2, nae)
# (2, nab)
# (2, men)
# (2, lye)
# (2, lit)
# (2, lis)
# (2, lin)
# (2, lig)
# (2, lie)
# (2, lid)
# (2, lib)
# (2, lez)
# (2, ley)
# (2, lex)
# (2, lew)
# (2, lev)
# (2, leu)
# (2, let)
# (2, les)
# (2, lek)
# (2, lei)
# (2, leg)
# (2, lee)
# (2, led)
# (2, lea)
# (2, kin)
# (2, ken)
# (2, jin)
# (2, its)
# (2, ita)
# (2, iso)
# (2, ism)
# (2, ish)
# (2, irk)
# (2, ire)
# (2, ios)
# (2, ion)
# (2, ins)
# (2, ink)
# (2, in)
# (2, ill)
# (2, ilk)
# (2, ide)
# (2, ice)
# (2, hin)
# (2, hie)
# (2, hen)
# (2, gu)
# (2, go)
# (2, gin)
# (2, gie)
# (2, gen)
# (2, fin)
# (2, fie)
# (2, fen)
# (2, euk)
# (2, eth)
# (2, eta)
# (2, est)
# (2, ess)
# (2, ers)
# (2, err)
# (2, ern)
# (2, erk)
# (2, erg)
# (2, erf)
# (2, ere)
# (2, era)
# (2, eon)
# (2, ens)
# (2, eng)
# (2, ene)
# (2, end)
# (2, en)
# (2, elt)
# (2, els)
# (2, elm)
# (2, ell)
# (2, elk)
# (2, elf)
# (2, eld)
# (2, eik)
# (2, een)
# (2, eel)
# (2, eek)
# (2, eau)
# (2, eat)
# (2, eas)
# (2, ear)
# (2, ean)
# (2, do)
# (2, din)
# (2, die)
# (2, den)
# (2, dei)
# (2, da)
# (2, bin)
# (2, ben)
# (2, aye)
# (2, axe)
# (2, awn)
# (2, awe)
# (2, ave)
# (2, aue)
# (2, ate)
# (2, are)
# (2, any)
# (2, ant)
# (2, ann)
# (2, ani)
# (2, ane)
# (2, and)
# (2, ana)
# (2, ami)
# (2, ale)
# (2, ake)
# (2, ait)
# (2, ais)
# (2, air)
# (2, ain)
# (2, aim)
# (2, ail)
# (2, aid)
# (2, aia)
# (2, ahi)
# (2, age)
# (2, ace)
# (1, ye)
# (1, xi)
# (1, we)
# (1, ut)
# (1, us)
# (1, ur)
# (1, un)
# (1, um)
# (1, uh)
# (1, ug)
# (1, to)
# (1, ti)
# (1, te)
# (1, ta)
# (1, st)
# (1, so)
# (1, si)
# (1, sh)
# (1, re)
# (1, qi)
# (1, oy)
# (1, ox)
# (1, ow)
# (1, ou)
# (1, os)
# (1, or)
# (1, oo)
# (1, on)
# (1, om)
# (1, oi)
# (1, oh)
# (1, of)
# (1, oe)
# (1, od)
# (1, ob)
# (1, ny)
# (1, nu)
# (1, no)
# (1, na)
# (1, mi)
# (1, me)
# (1, lo)
# (1, li)
# (1, la)
# (1, ki)
# (1, it)
# (1, is)
# (1, io)
# (1, if)
# (1, id)
# (1, hi)
# (1, he)
# (1, gi)
# (1, fe)
# (1, ex)
# (1, et)
# (1, es)
# (1, er)
# (1, em)
# (1, el)
# (1, eh)
# (1, ef)
# (1, ee)
# (1, ed)
# (1, ea)
# (1, di)
# (1, de)
# (1, bi)
# (1, be)
# (1, ay)
# (1, ax)
# (1, aw)
# (1, at)
# (1, as)
# (1, ar)
# (1, an)
# (1, am)
# (1, al)
# (1, ai)
# (1, ah)
# (1, ag)
# (1, ae)
# (1, ad)
# (1, ab)
# (1, aa)
# Total number of words: 2734

# %%
""" Produces a list of all words and scores that matches our expectations """

# test whether your output matches our expectation
cmd = ['python', 'scrabble.py', 'Penguin']
test = bytes.decode(subprocess.Popen(cmd, stdout=subprocess.PIPE).communicate()[0])
solution = '(10, penguin)\n(9, pening)\n(8, unpeg)\n(8, genip)\n(7, unpin)\n(7, unpen)\n(7, pung)\n(7, ping)\n(7, penni)\n(7, ingenu)\n(6, pug)\n(6, pine)\n(6, pig)\n(6, peni)\n(6, pein)\n(6, peg)\n(6, gup)\n(6, gip)\n(5, pun)\n(5, piu)\n(5, pin)\n(5, pie)\n(5, pen)\n(5, nip)\n(5, nep)\n(5, ginn)\n(5, gien)\n(5, genu)\n(5, ennui)\n(4, up)\n(4, pi)\n(4, pe)\n(4, nine)\n(4, neg)\n(4, gun)\n(4, gue)\n(4, gnu)\n(4, gin)\n(4, gie)\n(4, gen)\n(4, eng)\n(3, uni)\n(3, ug)\n(3, nun)\n(3, nie)\n(3, inn)\n(3, gu)\n(3, gi)\n(2, un)\n(2, nu)\n(2, ne)\n(2, in)\n(2, en)\nTotal number of words: 53\n'

print("\nDoes your output match our expectation?", test == solution)
# Out:
# Does your output match our expectation? True

# %%
""" The code should run in seconds to two minutes """

import time
start = time.time()

#test the code in the command line
cmd = ['python', 'scrabble.py', 'PENGU*?']
out = bytes.decode(subprocess.Popen(cmd, stdout=subprocess.PIPE).communicate()[0])

tot_time = time.time() - start
print('Total time was {} seconds'.format(tot_time))
assert_less(tot_time, 120)
# Out:
# Total time was 0.758770227432251 seconds

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
# Autograding test

# %%
"""Implement extra credit call run the code here
   If this cell isnt filled out - we'll assume the extra credit wasn't done
   Please write a comment on how to use your extra credit syntax also!
"""

# YOUR CODE HERE
# 1st argument should be the rack; 2nd should be the special letter; 3rd should be the special spot that the letter 
# would be located. 
# !python scrabble.py Pe* e 2
# Out:
# (4, zep)
# (4, yep)
# (4, rep)
# (4, pew)
# (4, pet)
# (4, pes)
# (4, per)
# (4, pep)
# (4, pen)
# (4, peh)
# (4, peg)
# (4, pee)
# (4, ped)
# (4, pec)
# (4, pea)
# (4, pe)
# (4, nep)
# (4, lep)
# (4, kep)
# (4, hep)
# (4, cep)
# (1, ye)
# (1, we)
# (1, te)
# (1, re)
# (1, oe)
# (1, ne)
# (1, me)
# (1, he)
# (1, fe)
# (1, ee)
# (1, de)
# (1, be)
# (1, ae)
# Total number of words: 34

# %% [markdown]
# ## If you have feedback for this homework, please submit it using the link below:
#
# http://goo.gl/forms/74yCiQTf6k
